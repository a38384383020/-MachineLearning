# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

iris=load_iris()
iris_data=iris.data
iris_label=iris.target

train_data,test_data,train_label,test_label=train_test_split(iris_data,iris_label, test_size=0.3)
clf=GaussianNB()
clf.fit(train_data, train_label)
print("訓練資訊正確率: ",clf.score(train_data,train_label))
print("測試資訊正確率: ",clf.score(test_data,test_label))
predict=clf.predict(test_data)
print("標準答案:",test_label) # 標準答案
print("預測答案:",predict) # 預測答案
# Out:
# 訓練資訊正確率:  0.9523809523809523
# 測試資訊正確率:  0.9333333333333333
# 標準答案: [0 2 1 1 1 2 0 2 0 2 0 1 1 0 2 2 0 0 0 1 1 0 2 2 2 1 0 0 1 0 2 1 2 1 1 1 1
#  0 0 1 2 0 2 0 2]
# 預測答案: [0 1 2 1 1 2 0 2 0 2 0 1 1 0 2 2 0 0 0 1 1 0 2 2 2 1 0 0 2 0 2 1 2 1 1 1 1
#  0 0 1 2 0 2 0 2]
